# %%
from openai import OpenAI

client = OpenAI(api_key="__<MY API KEY>__")

# %% [markdown]
# # Generating and transforming text

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    max_tokens=100,
  
    # Enter your prompt
    messages=[{"role": "user", "content": "How many days are in October?"}]
)

print(response.choices[0].message.content)
# Out:
# October has 31 days.

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
  
    # Enter your prompt
    messages=[{"role": "user", "content": "Life is like a box of Chocolates?"}],
    temperature = 0 # temperature: control on determinism which ranges from 0-2 (highly deterministic ~ very random)
)

print(response.choices[0].message.content)
# Out:
# The phrase "Life is like a box of chocolates" comes from the movie *Forrest Gump*. It suggests that life is full of surprises and uncertainties, much like a box of assorted chocolates where you never know what you're going to get. Each chocolate represents different experiences, some sweet and enjoyable, while others may be less pleasant. The idea encourages embracing the unpredictability of life and finding joy in the journey, regardless of the challenges that may arise. What are your thoughts on this metaphor?

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
  
    # Enter your prompt
    messages=[{"role": "user", "content": "Life is like a box of Chocolates?"}],
    temperature = 1 # temperature: control on determinism which ranges from 0-2 (highly deterministic ~ very random)
)

print(response.choices[0].message.content)
# Out:
# The phrase "Life is like a box of chocolates" comes from the movie *Forrest Gump*. It suggests that life is full of surprises and unpredictable experiences, much like opening a box of assorted chocolates—you never quite know what you're going to get. Each chocolate represents different moments, emotions, and challenges we encounter in life. The metaphor encourages embracing the unknown and appreciating the variety that life offers, even if some experiences are bittersweet. Would you like to explore this theme further?

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
  
    # Enter your prompt
    messages=[{"role": "user", "content": "Life is like a box of Chocolates?"}],
    temperature = 2 # temperature: control on determinism which ranges from 0-2 (highly deterministic ~ very random)
)

print(response.choices[0].message.content)
# Out:
# The phrase "Life is like a box of chocolates" comes from the film *Forrest Gump* and often serves as a metaphor for uncertainty and the variety of experiences in life. Just like a box of assorted chocolates, life presents myriad surprises, from enjoyable moments to challenges, and you never quite know what you’ll get next. It encourages us to embrace whatever comes our way, explore new opportunities, and appreciate the range of joys and obstacles that enrich our journey. Is there anything specific about the metaphor you'd like to explore further?

# %%
prompt="""Replace car with plane and adjust phrase:
A car is a vehicle that is typically powered by an internal combustion engine or an electric motor. It has four wheels, and is designed to carry passengers and/or cargo on roads or highways. Cars have become a ubiquitous part of modern society, and are used for a wide variety of purposes, such as commuting, travel, and transportation of goods. Cars are often associated with freedom, independence, and mobility."""

# Create a request to the Chat Completions endpoint
response = client.chat.completions.create(
  model="gpt-4o-mini",
  messages=[{"role": "user", "content": prompt}],
  max_tokens=100
)

# Extract and print the response text
print(response.choices[0].message.content)
# Out:
# A plane is a vehicle that is typically powered by jet engines or propellers. It has wings and is designed to carry passengers and/or cargo through the air. Planes have become a ubiquitous part of modern society, and are used for a wide variety of purposes, such as travel, commuting, and transportation of goods. Planes are often associated with freedom, independence, and mobility.

# %%
prompt="""Summarize the following text into two concise bullet points:
Investment refers to the act of committing money or capital to an enterprise with the expectation of obtaining an added income or profit in return. There are a variety of investment options available, including stocks, bonds, mutual funds, real estate, precious metals, and currencies. Making an investment decision requires careful analysis, assessment of risk, and evaluation of potential rewards. Good investments have the ability to produce high returns over the long term while minimizing risk. Diversification of investment portfolios reduces risk exposure. Investment can be a valuable tool for building wealth, generating income, and achieving financial security. It is important to be diligent and informed when investing to avoid losses."""

# Create a request to the Chat Completions endpoint
response = client.chat.completions.create(
  model="gpt-4o-mini",
  messages=[{"role": "user", "content": prompt}],
  temperature = 0,
  max_tokens=400
)

print(response.choices[0].message.content)
# Out:
# - Investment involves committing capital to various options (e.g., stocks, bonds, real estate) with the expectation of generating profit, requiring careful analysis of risks and potential rewards.
# - Diversifying investment portfolios can minimize risk and enhance long-term returns, making informed investing crucial for wealth building and financial security.

# %%
# Create a request to the Chat Completions endpoint
response = client.chat.completions.create(
  model="gpt-4o-mini",
  messages=[{"role": "user", "content": "Slogan for a new restaurant"}],
  max_tokens=100
)

print(response.choices[0].message.content)
# Out:
# "Flavors Worth Savoring!"

# %% [markdown]
# # Sentiment analysis and classification

# %%
# Define a multi-line prompt to classify sentiment
prompt = """classify the sentiment of the following statements as either negative, positive, or neutral:
1. Unbelievably good!
2. Shoes fell apart on the second use.
3. The shoes look nice, but they aren't very comfortable.
4. Can't wait to show them off!"""

# Create a request to the Chat Completions endpoint
response = client.chat.completions.create(
  model="gpt-4o-mini",
  messages=[{"role": "user", "content": prompt}],
  max_tokens=100
)

print(response.choices[0].message.content)
# Out:
# 1. Positive
# 2. Negative
# 3. Neutral
# 4. Positive

# %%
# Define a prompt for the categorization
prompt = "categorize the following companies:: Apple, Microsoft, Saudi Aramco, Alphabet, Amazon, Berkshire Hathaway, NVIDIA, Meta, Tesla, LVMH"

# Create a request to the Chat Completions endpoint
response = client.chat.completions.create(
  model="gpt-4o-mini",
  messages=[{"role": "user", "content": prompt}],
  max_tokens=200,
  temperature=0
)

print(response.choices[0].message.content)
# Out:
# Here’s a categorization of the companies you listed based on their primary industry sectors:
#
# ### Technology
# - **Apple**: Consumer Electronics, Software
# - **Microsoft**: Software, Cloud Computing
# - **Alphabet**: Internet Services, Technology
# - **Amazon**: E-commerce, Cloud Computing
# - **NVIDIA**: Semiconductors, Graphics Processing
# - **Meta**: Social Media, Technology
# - **Tesla**: Automotive, Energy Solutions
#
# ### Energy
# - **Saudi Aramco**: Oil and Gas
#
# ### Conglomerate
# - **Berkshire Hathaway**: Diversified Investments, Conglomerate
#
# ### Luxury Goods
# - **LVMH**: Luxury Goods, Fashion
#
# This categorization reflects the primary focus of each company within its respective industry.

# %% [markdown]
# # Chat completions with GPT

# %%
# Create a request to the Chat Completions endpoint
response = client.chat.completions.create(
  model="gpt-4o-mini",
  max_tokens=150,
  messages=[
    {"role": "system",
     "content": "You are a helpful data science tutor."},
    {"role": "user",
     "content": "What is the difference between a for loop and a while loop?"},
  ]
)

# Extract the assistant's text response
print(response.choices[0].message.content)
# Out:
# A **for loop** and a **while loop** are both control flow statements in programming that allow you to execute a block of code multiple times. However, they operate in different ways and are used in different situations. Here are the key differences:
#
# ### Structure
#
# - **For Loop**:
#   A for loop typically iterates over a range or a collection, such as a list or an array. It is generally used when the number of iterations is known beforehand.
#
#   **Example in Python**:
#   ```python
#   for i in range(5):
#       print(i)
#   ```
#   In this example, the loop will print numbers from 0 to 4, and the number of iterations is predetermined by the `range(5)`

# %%
# Create a request to the Chat Completions endpoint
response = client.chat.completions.create(
  model="gpt-4o-mini",
  max_tokens=150,
  messages=[
    {"role": "system",
     "content": "You are a helpful data science tutor."},
    {"role": "user",
     "content": "What is the difference between a for loop and a while loop?"},
  ]
)

# Extract the assistant's text response
print(response.choices[0].message.content)
# Out:
# Both `for` loops and `while` loops are control flow statements used in programming to execute a block of code multiple times, but they are used in different scenarios and have distinct characteristics:
#
# ### For Loop
# - **Usage**: Typically used when the number of iterations is known beforehand (e.g., iterating over a range of numbers or a collection like a list or an array).
# - **Structure**: It often includes initialization, condition, and increment/decrement statements in one line.
# - **Syntax** (in Python, for example):
#   ```python
#   for i in range(5):  # This will loop from 0 to 4
#       print(i)
#   ```
# - **Example Use Case**: When you need

# %%
instruction = """Explain what this Python code does in one sentence:
import numpy as np

heights_dict = {"Mark": 1.76, "Steve": 1.88, "Adnan": 1.73}
heights = heights_dict.values()
print(np.mean(heights))
"""

# Create a request to the Chat Completions endpoint
response = client.chat.completions.create(
  model="gpt-4o-mini",
  messages=[
    {"role": "system", "content": "You are a helpful Python programming assistant."},
    {"role": "user", "content": instruction}
  ],
  max_tokens=100
)

print(response.choices[0].message.content)
# Out:
# The code imports the NumPy library, creates a dictionary of heights for three individuals, extracts the heights as a view, and then computes and prints the average height using NumPy's mean function.

# %% [markdown]
# # Multi-turn chat completions with GPT

# %%
response = client.chat.completions.create(
   model="gpt-4o-mini",
   # Add a user and assistant message for in-context learning
   messages=[
     {"role": "system", "content": "You are a helpful Python programming tutor."},
     {"role": "user", "content": "Explain what the min() function does."},
     {"role": "assistant", "content": "The min() function returns the smallest item from an iterable."},
     {"role": "user", "content": "Explain what the type() function does."}
   ]
)

print(response.choices[0].message.content)
# Out:
# The `type()` function in Python is used to determine the type of an object. It returns the type of the specified object passed to it as an argument.
#
# ### Syntax
# ```python
# type(object)
# ```
#
# ### Parameters
# - **object**: The object whose type you want to check.
#
# ### Returns
# - The function returns the type of the given object as a type object.
#
# ### Examples
#
# 1. Checking the type of a number:
#     ```python
#     num = 42
#     print(type(num))  # Output: <class 'int'>
#     ```
#
# 2. Checking the type of a string:
#     ```python
#     text = "Hello, World!"
#     print(type(text))  # Output: <class 'str'>
#     ```
#
# 3. Checking the type of a list:
#     ```python
#     my_list = [1, 2, 3]
#     print(type(my_list))  # Output: <class 'list'>
#     ```
#
# 4. Using it to check custom classes:
#     ```python
#     class MyClass:
#         pass
#
#     obj = MyClass()
#     print(type(obj))  # Output: <class '__main__.MyClass'>
#     ```
#
# Overall, the `type()` function is useful for debugging and understanding the types of data you're working with in Python.

# %%
messages = [{"role": "system", "content": "You are a helpful math tutor."}]
user_msgs = ["Explain what pi is.", "Summarize this in two bullet points."]

for q in user_msgs:
    print("User: ", q)
    
    # Create a dictionary for the user message from q and append to messages
    user_dict = {"role": "user", "content": q}
    messages.append(user_dict)
    
    # Create the API request
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages = messages,
        max_tokens=100
    )
    
    # Convert the assistant's message to a dict and append to messages
    assistant_dict = {"role": "assistant", "content": response.choices[0].message.content}
    messages.append(assistant_dict)
    print("Assistant: ", response.choices[0].message.content, "\n")
# Out:
# User:  Explain what pi is.
# Assistant:  Pi, denoted by the symbol \( \pi \), is a mathematical constant that represents the ratio of a circle's circumference to its diameter. This means that no matter the size of the circle, if you divide the circumference (the distance around the circle) by the diameter (the distance across the circle through the center), you will always get the same value: \( \pi \).
#
# The value of \( \pi \) is approximately 3.14159, but it is an irrational number
#
# User:  Summarize this in two bullet points.
# Assistant:  - Pi (\( \pi \)) is the ratio of a circle's circumference to its diameter, constant for all circles.
# - The approximate value of \( \pi \) is 3.14159, and it is an irrational number, meaning it cannot be expressed as a simple fraction and has an infinite, non-repeating decimal representation.
