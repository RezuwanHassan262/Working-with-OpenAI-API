# %%
from openai import OpenAI

client = OpenAI(api_key="__<MY API KEY>__")

# %% [markdown]
# # First request

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    max_tokens=100,
  
    # Enter your prompt
    messages=[{"role": "user", "content": "Why is learning the OpenAI API valuable for developers?"}]
)

print(response.choices[0].message.content)
# Out:
# Learning the OpenAI API is valuable for developers for several reasons:
#
# 1. **Access to Advanced AI Capabilities**: The OpenAI API provides access to state-of-the-art natural language processing models, allowing developers to integrate sophisticated AI capabilities into their applications without needing to build complex models from scratch.
#
# 2. **Versatility Across Applications**: The API can be utilized in a wide range of applications, including chatbots, content generation, translation, summarization, code assistance, and more. This versatility

# %% [markdown]
# # Building an OpenAI API request

# %%
# Create a request to the Chat Completions endpoint
response = client.chat.completions.create(
  model="gpt-4o-mini",
  messages=[
    {"role": "user", 
     "content": "Write a polite reply accepting an AI Engineer job offer."}]
)

print(response.choices[0].message.content)
# Out:
# Subject: Acceptance of Job Offer – AI Engineer Position
#
# Dear [Hiring Manager's Name],
#
# I hope this message finds you well.
#
# I am writing to formally accept the offer for the AI Engineer position at [Company Name]. I am thrilled about the opportunity to join such an innovative team and contribute to the exciting projects at [Company Name].
#
# Thank you for the detailed information regarding the terms of employment. I am looking forward to starting on [Start Date] and collaborating with everyone at [Company Name].
#
# If there are any specific documents or further information needed from my side before my start date, please let me know.
#
# Thank you once again for this opportunity. I am eager to begin this new chapter in my career.
#
# Kind regards,
#
# [Your Name]
# [Your LinkedIn Profile] (if applicable)
# [Your Phone Number]
# [Your Email Address]

# %% [markdown]
# # Specifying an OpenAI model

# %%
response = client.chat.completions.create(
  # Specify the model
  model="gpt-4o-mini",
  messages=[
    # Assign the correct role
    {"role": "user", 
     "content": "Announce my new AI Engineer role on LinkedIn."}]
)

print(response.choices[0].message.content)
# Out:
# Sure! Here’s a suggestion for your LinkedIn announcement:
#
# ---
#
# 🌟 Exciting News! 🚀
#
# I am thrilled to share that I have accepted a new position as an AI Engineer! 🎉
#
# I am eager to dive into this role and contribute to the innovative projects that leverage artificial intelligence to drive impactful solutions. I look forward to collaborating with talented colleagues, learning from industry leaders, and pushing the boundaries of technology.
#
# A heartfelt thank you to everyone who has supported me on this journey. Your encouragement means the world! 🙏
#
# Let’s connect and explore the exciting possibilities in the world of AI!
#
# #NewBeginnings #AIEngineer #CareerGrowth #ArtificialIntelligence #Innovation
#
# ---
#
# Feel free to customize any part of this announcement to better fit your style or details related to the new role!

# %%
response = client.chat.completions.create(
  # Specify the model
  model="gpt-4o-mini",
  messages=[
    # Assign the correct role
    {"role": "system", 
     "content": "Announce my new AI Engineer role on LinkedIn."}]
)

print(response.choices[0].message.content)
# Out:
# 🌟 Exciting News! 🌟
#
# I'm thrilled to announce that I've accepted a new role as an AI Engineer! 🚀
#
# As I step into this exciting chapter, I'm eager to delve deeper into the world of artificial intelligence, collaborating with talented teams to drive innovation and create impactful solutions.
#
# A huge thank you to everyone who has supported me on this journey so far—your encouragement means the world to me. I can't wait to share insights and learnings from this new role, and I'm looking forward to connecting with industry peers and expanding my professional network.
#
# Here’s to new beginnings and endless possibilities! 🤖💼
#
# #NewRole #AIEngineer #ArtificialIntelligence #CareerMove #Excited

# %%
response = client.chat.completions.create(
  # Specify the model
  model="gpt-4o-mini",
  messages=[
    # Assign the correct role
    {"role": "assistant", 
     "content": "Announce my new AI Engineer role on LinkedIn."}]
)

print(response.choices[0].message.content)
# Out:
# Certainly! Here’s a suggestion for your LinkedIn announcement to share your new AI Engineer role:
#
# ---
#
# 🌟 Exciting News! 🌟
#
# I am thrilled to announce that I have accepted a new position as an AI Engineer at [Company Name]! 🚀
#
# I am incredibly grateful for this opportunity to work alongside an amazing team dedicated to developing cutting-edge AI solutions that drive innovation and transform industries. My passion for artificial intelligence and its applications has only grown, and I am eager to contribute my skills in [mention specific skills or technologies you'll be using, if relevant].
#
# Thank you to everyone who has supported me on my journey. I look forward to connecting with my new colleagues and taking on new challenges in the fascinating world of AI!
#
# Here’s to new beginnings! 🎉
#
# #NewJob #AIEngineer #ArtificialIntelligence #CareerGrowth #Excited
#
# ---
#
# Feel free to modify any part to make it more personal! Congratulations on your new role!

# %% [markdown]
# # Digging into the response

# %%
response = client.chat.completions.create(
  model="gpt-4o-mini",
  messages=[{"role": "user", "content": "Quick productivity tip."}]
)

# Extract the content from the response
print(response.choices[0].message.content)
# Out:
# One effective productivity tip is to use the "Pomodoro Technique." Set a timer for 25 minutes and focus on a single task without any distractions. After the timer goes off, take a 5-minute break. Repeat this cycle four times, and then take a longer break (15-30 minutes). This method helps maintain focus, reduces burnout, and can improve overall efficiency.
